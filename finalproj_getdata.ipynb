# %%
# Based on https://github.com/GregorUT/vgchartzScrape, will submit changes when I have more than 32 free seconds - basically
# the vgchartz site changed and that borked the A-tag scrubbing

from bs4 import BeautifulSoup, element
import urllib
import pandas as pd
import numpy as np
import re

pages = 19
rec_count = 0
rank = []
gname = []
platform = []
year = []
genre = []
critic_score = []
user_score = []
publisher = []
developer = []
sales_na = []
sales_pal = []
sales_jp = []
sales_ot = []
sales_gl = []

urlhead = 'http://www.vgchartz.com/gamedb/?page='
urltail = '&console=&region=All&developer=&publisher=&genre=&boxart=Both&ownership=Both'
urltail += '&results=1000&order=Sales&showtotalsales=0&showtotalsales=1&showpublisher=0'
urltail += '&showpublisher=1&showvgchartzscore=0&shownasales=1&showdeveloper=1&showcriticscore=1'
urltail += '&showpalsales=0&showpalsales=1&showreleasedate=1&showuserscore=1&showjapansales=1'
urltail += '&showlastupdate=0&showothersales=1&showgenre=1&sort=GL'

for page in range(1, pages):
    surl = urlhead + str(page) + urltail
    r = urllib.request.urlopen(surl).read()
    soup = BeautifulSoup(r)
    print(f"Page: {page}")

    # vgchartz website is really weird so we have to search for
    # <a> tags with game urls
    # game_tags = list(filter(
    #     lambda x: x.attrs['href'].startswith('http://www.vgchartz.com/game/'),
    #     # discard the first 10 elements because those
    #     # links are in the navigation bar
    #     soup.find_all("a")
    # ))[10:]
    game_tags = soup.find_all("a", {"href": re.compile(r"^https://www\.vgchartz\.com/game/")})
    

    for tag in game_tags:

        # add name to list
        gname.append(" ".join(tag.string.split()))
        print(f"{rec_count + 1} Fetch data for game {gname[-1]}")

        # get different attributes
        # traverse up the DOM tree
        data = tag.parent.parent.find_all("td")
        rank.append(np.int32(data[0].string))
        platform.append(data[3].find('img').attrs['alt'])
        publisher.append(data[4].string)
        developer.append(data[5].string)
        critic_score.append(
            float(data[6].string) if
            not data[6].string.startswith("N/A") else np.nan)
        user_score.append(
            float(data[7].string) if
            not data[7].string.startswith("N/A") else np.nan)
        sales_na.append(
            float(data[9].string[:-1]) if
            not data[9].string.startswith("N/A") else np.nan)
        sales_pal.append(
            float(data[10].string[:-1]) if
            not data[10].string.startswith("N/A") else np.nan)
        sales_jp.append(
            float(data[11].string[:-1]) if
            not data[11].string.startswith("N/A") else np.nan)
        sales_ot.append(
            float(data[12].string[:-1]) if
            not data[12].string.startswith("N/A") else np.nan)
        sales_gl.append(
            float(data[8].string[:-1]) if
            not data[8].string.startswith("N/A") else np.nan)
        release_year = data[13].string.split()[-1]
        # different format for year
        if release_year.startswith('N/A'):
            year.append('N/A')
        else:
            if int(release_year) >= 80:
                year_to_add = np.int32("19" + release_year)
            else:
                year_to_add = np.int32("20" + release_year)
            year.append(year_to_add)

        # go to every individual website to get genre info
        url_to_game = tag.attrs['href']
        site_raw = urllib.request.urlopen(url_to_game).read()
        sub_soup = BeautifulSoup(site_raw, "html.parser")
        # again, the info box is inconsistent among games so we
        # have to find all the h2 and traverse from that to the genre name
        h2s = sub_soup.find("div", {"id": "gameGenInfoBox"}).find_all('h2')
        # make a temporary tag here to search for the one that contains
        # the word "Genre"
        temp_tag = element.Tag
        for h2 in h2s:
            if h2.string == 'Genre':
                temp_tag = h2
        genre.append(temp_tag.next_sibling.string)

        rec_count += 1

columns = {
    'Rank': rank,
    'Name': gname,
    'Platform': platform,
    'Year': year,
    'Genre': genre,
    'Critic_Score': critic_score,
    'User_Score': user_score,
    'Publisher': publisher,
    'Developer': developer,
    'NA_Sales': sales_na,
    'PAL_Sales': sales_pal,
    'JP_Sales': sales_jp,
    'Other_Sales': sales_ot,
    'Global_Sales': sales_gl
}
print(rec_count)
df = pd.DataFrame(columns)
print(df.columns)
df = df[[
    'Rank', 'Name', 'Platform', 'Year', 'Genre',
    'Publisher', 'Developer', 'Critic_Score', 'User_Score',
    'NA_Sales', 'PAL_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']]
df.to_csv("vgsales.csv", sep=",", encoding='utf-8', index=False)
# Out:
# Page: 1
# 1 Fetch data for game Tetris
# 2 Fetch data for game Pokemon
# 3 Fetch data for game Call of Duty
# 4 Fetch data for game Super Mario
# 5 Fetch data for game Grand Theft Auto
# 6 Fetch data for game FIFA
# 7 Fetch data for game Minecraft
# 8 Fetch data for game Minecraft
# 9 Fetch data for game Lego
# 10 Fetch data for game Assassin's Creed
# 11 Fetch data for game The Sims
# 12 Fetch data for game Grand Theft Auto V
# 13 Fetch data for game Final Fantasy
# 14 Fetch data for game Mario Kart
# 15 Fetch data for game Resident Evil
# 16 Fetch data for game The Legend of Zelda
# 17 Fetch data for game Need for Speed
# 18 Fetch data for game NBA 2K
# 19 Fetch data for game Tomb Raider
# 20 Fetch data for game Madden NFL
# 21 Fetch data for game Wii/Nintendo Sports
# 22 Fetch data for game Pro Evolution Soccer/eFootball
# 23 Fetch data for game Sonic the Hedgehog
# 24 Fetch data for game Monster Hunter
# 25 Fetch data for game The Elder Scrolls
# 26 Fetch data for game Gran Turismo
# 27 Fetch data for game Dragon Quest
# 28 Fetch data for game Battlefield
# 29 Fetch data for game Red Dead
# 30 Fetch data for game Borderlands
# 31 Fetch data for game Mortal Kombat
# 32 Fetch data for game Wii Sports
# 33 Fetch data for game Halo
# 34 Fetch data for game Animal Crossing
# 35 Fetch data for game Just Dance
# 36 Fetch data for game God of War
# 37 Fetch data for game Super Smash Bros.
# 38 Fetch data for game Mario Party
# 39 Fetch data for game PlayerUnknown's Battlegrounds
# 40 Fetch data for game PUBG
# 41 Fetch data for game The Witcher
# 42 Fetch data for game Worms
# 43 Fetch data for game WWE 2K
# 44 Fetch data for game Dragon Ball
# 45 Fetch data for game Civilization
# 46 Fetch data for game Harry Potter/Wizarding World
# 47 Fetch data for game Counter-Strike
# 48 Fetch data for game Donkey Kong
# 49 Fetch data for game The Oregon Trail
# 50 Fetch data for game Mario Kart 8 Deluxe
# 51 Fetch data for game Metal Gear
# 52 Fetch data for game Red Dead Redemption 2
# 53 Fetch data for game Star Wars: Battlefront
# 54 Fetch data for game The Elder Scrolls V: Skyrim
# 55 Fetch data for game Spider-Man
# 56 Fetch data for game Tekken
# 57 Fetch data for game Crash Bandicoot
# 58 Fetch data for game Diablo
# 59 Fetch data for game Lego Star Wars
# 60 Fetch data for game Street Fighter
# 61 Fetch data for game Far Cry
# 62 Fetch data for game Fallout
# 63 Fetch data for game Kirby
# 64 Fetch data for game The Walking Dead: Telltale Games Series
# 65 Fetch data for game Bejeweled
# 66 Fetch data for game Destiny
# 67 Fetch data for game Human: Fall Flat
# 68 Fetch data for game Marvel's Spider-Man
# 69 Fetch data for game The Witcher 3: Wild Hunt
# 70 Fetch data for game Warriors
# 71 Fetch data for game Animal Crossing: New Horizons
# 72 Fetch data for game Total War
# 73 Fetch data for game Terraria
# 74 Fetch data for game Terraria
# 75 Fetch data for game Uncharted
# 76 Fetch data for game Wii Fit
# 77 Fetch data for game BioShock
# 78 Fetch data for game Gears of War
# 79 Fetch data for game Mega Man
# 80 Fetch data for game World of WarCraft
# 81 Fetch data for game Super Mario Bros.
# 82 Fetch data for game Counter-Strike: Global Offensive
# 83 Fetch data for game Guitar Hero
# 84 Fetch data for game Medal of Honor
# 85 Fetch data for game Souls
# 86 Fetch data for game The Last of Us
# 87 Fetch data for game Mario Kart Wii
# 88 Fetch data for game PLAYERUNKNOWN'S BATTLEGROUNDS
# 89 Fetch data for game Kingdom Hearts
# 90 Fetch data for game Tom Clancy's Rainbow Six
# 91 Fetch data for game Dark Souls
# 92 Fetch data for game Brain Age
# 93 Fetch data for game NBA Live
# 94 Fetch data for game Tetris
# 95 Fetch data for game Tom Clancy's Ghost Recon
# 96 Fetch data for game Super Smash Bros. Ultimate
# 97 Fetch data for game Ratchet & Clank
# 98 Fetch data for game The Legend of Zelda: Breath of the Wild
# 99 Fetch data for game Football Manager
# 100 Fetch data for game Minecraft
# 101 Fetch data for game Wii Sports Resort
# 102 Fetch data for game Half-life
# 103 Fetch data for game Horizon
# 104 Fetch data for game Naruto: Ultimate Ninja
# 105 Fetch data for game Saints Row
# 106 Fetch data for game The Legend of Zelda: Breath of the Wild
# 107 Fetch data for game Pokémon Red / Green / Blue Version
# 108 Fetch data for game Tony Hawk's
# 109 Fetch data for game Call of Duty: Black Ops II
# 110 Fetch data for game Tom Clancy's Splinter Cell
# 111 Fetch data for game Mario & Sonic at the Olympic Games
# 112 Fetch data for game Age of Empires
# 113 Fetch data for game New Super Mario Bros.
# 114 Fetch data for game Splatoon
# 115 Fetch data for game New Super Mario Bros. Wii
# 116 Fetch data for game Tales of
# 117 Fetch data for game Call of Duty: Black Ops
# 118 Fetch data for game Call of Duty: Modern Warfare
# 119 Fetch data for game Call of Duty: Modern Warfare 3
# 120 Fetch data for game Call of Duty: Vanguard
# 121 Fetch data for game Command & Conquer
# 122 Fetch data for game Devil May Cry
# 123 Fetch data for game Diablo III
# 124 Fetch data for game Dying Light
# 125 Fetch data for game James Bond
# 126 Fetch data for game Spyro
# 127 Fetch data for game Stardew Valley
# 128 Fetch data for game Stardew Valley
# 129 Fetch data for game Wii Play
# 130 Fetch data for game Nintendogs
# 131 Fetch data for game Duck Hunt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 94
#      92 # go to every individual website to get genre info
#      93 url_to_game = tag.attrs['href']
# ---> 94 site_raw = urllib.request.urlopen(url_to_game).read()
#      95 sub_soup = BeautifulSoup(site_raw, "html.parser")
#      96 # again, the info box is inconsistent among games so we
#      97 # have to find all the h2 and traverse from that to the genre name
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:473, in HTTPResponse.read(self, amt)
#     470     return b""
#     472 if self.chunked:
# --> 473     return self._read_chunked(amt)
#     475 if amt is not None:
#     476     if self.length is not None and amt > self.length:
#     477         # clip the read to the "end of response"
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:595, in HTTPResponse._read_chunked(self, amt)
#     593 value = []
#     594 try:
# --> 595     while (chunk_left := self._get_chunk_left()) is not None:
#     596         if amt is not None and amt <= chunk_left:
#     597             value.append(self._safe_read(amt))
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:579, in HTTPResponse._get_chunk_left(self)
#     577     self._safe_read(2)  # toss the CRLF at the end of the chunk
#     578 try:
# --> 579     chunk_left = self._read_next_chunk_size()
#     580 except ValueError:
#     581     raise IncompleteRead(b'')
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:539, in HTTPResponse._read_next_chunk_size(self)
#     537 def _read_next_chunk_size(self):
#     538     # Read the next chunk size from the file
# --> 539     line = self.fp.readline(_MAXLINE + 1)
#     540     if len(line) > _MAXLINE:
#     541         raise LineTooLong("chunk size")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:
