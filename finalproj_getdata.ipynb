# %%
# Based on https://github.com/GregorUT/vgchartzScrape, will submit changes when I have more than 32 free seconds - basically
# the vgchartz site changed and that borked the A-tag scrubbing

from bs4 import BeautifulSoup, element
import urllib
import pandas as pd
import numpy as np
import re

startpage = 1
pages = 20
rec_count = 0
rank = []
gname = []
platform = []
year = []
genre = []
critic_score = []
user_score = []
publisher = []
developer = []
sales_na = []
sales_pal = []
sales_jp = []
sales_ot = []
sales_gl = []

urlhead = 'https://www.vgchartz.com/gamedb/?page='
urltail = '&console=&region=All&developer=&publisher=&genre=&boxart=Both&ownership=Both'
urltail += '&results=100&order=TotalSales&direction=DESC&showtotalsales=1&showpublisher=1'
urltail += '&&showvgchartzscore=0&shownasales=1&showdeveloper=1&showcriticscore=1'
urltail += '&showpalsales=0&showpalsales=1&showreleasedate=1&showuserscore=1&showjapansales=1'
urltail += '&showlastupdate=0&showothersales=1&showgenre=1'

for page in range(startpage, startpage + pages):
    surl = urlhead + str(page) + urltail
    r = urllib.request.urlopen(surl).read()
    soup = BeautifulSoup(r)
    print(f"Page: {page}")

    # vgchartz website is really weird so we have to search for
    # <a> tags with game urls
    # game_tags = list(filter(
    #     lambda x: x.attrs['href'].startswith('http://www.vgchartz.com/game/'),
    #     # discard the first 10 elements because those
    #     # links are in the navigation bar
    #     soup.find_all("a")
    # ))[10:]
    game_tags = soup.find_all("a", {"href": re.compile(r"^https://www\.vgchartz\.com/game/")})
    

    for tag in game_tags:

        # add name to list
        gname.append(" ".join(tag.string.split()))
        print(f"{rec_count + 1} Fetch data for game {gname[-1]}")

        # get different attributes
        # traverse up the DOM tree
        data = tag.parent.parent.find_all("td")
        rank.append(np.int32(data[0].string))
        platform.append(data[3].find('img').attrs['alt'])
        publisher.append(data[4].string)
        developer.append(data[5].string)
        critic_score.append(
            float(data[6].string) if
            not data[6].string.startswith("N/A") else np.nan)
        user_score.append(
            float(data[7].string) if
            not data[7].string.startswith("N/A") else np.nan)
        sales_na.append(
            float(data[9].string[:-1]) if
            not data[9].string.startswith("N/A") else np.nan)
        sales_pal.append(
            float(data[10].string[:-1]) if
            not data[10].string.startswith("N/A") else np.nan)
        sales_jp.append(
            float(data[11].string[:-1]) if
            not data[11].string.startswith("N/A") else np.nan)
        sales_ot.append(
            float(data[12].string[:-1]) if
            not data[12].string.startswith("N/A") else np.nan)
        sales_gl.append(
            float(data[8].string[:-1]) if
            not data[8].string.startswith("N/A") else np.nan)
        release_year = data[13].string.split()[-1]
        # different format for year
        if release_year.startswith('N/A'):
            year.append('N/A')
        else:
            if int(release_year) >= 80:
                year_to_add = np.int32("19" + release_year)
            else:
                year_to_add = np.int32("20" + release_year)
            year.append(year_to_add)

        # go to every individual website to get genre info
        url_to_game = tag.attrs['href']
        site_raw = urllib.request.urlopen(url_to_game).read()
        sub_soup = BeautifulSoup(site_raw, "html.parser")
        # again, the info box is inconsistent among games so we
        # have to find all the h2 and traverse from that to the genre name
        h2s = sub_soup.find("div", {"id": "gameGenInfoBox"}).find_all('h2')
        # make a temporary tag here to search for the one that contains
        # the word "Genre"
        temp_tag = element.Tag
        for h2 in h2s:
            if h2.string == 'Genre':
                temp_tag = h2
        genre.append(temp_tag.next_sibling.string)

        rec_count += 1

columns = {
    'Rank': rank,
    'Name': gname,
    'Platform': platform,
    'Year': year,
    'Genre': genre,
    'Critic_Score': critic_score,
    'User_Score': user_score,
    'Publisher': publisher,
    'Developer': developer,
    'NA_Sales': sales_na,
    'PAL_Sales': sales_pal,
    'JP_Sales': sales_jp,
    'Other_Sales': sales_ot,
    'Global_Sales': sales_gl
}
print(rec_count)
df = pd.DataFrame(columns)
print(df.columns)
df = df[[
    'Rank', 'Name', 'Platform', 'Year', 'Genre',
    'Publisher', 'Developer', 'Critic_Score', 'User_Score',
    'NA_Sales', 'PAL_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']]
df.to_csv("vgsales_new.csv", sep=",", encoding='utf-8', index=False)
# Out:
# Page: 20
# 1 Fetch data for game EA Sports Active: More Workouts
# 2 Fetch data for game Wario Land: Shake It!
# 3 Fetch data for game The Elder Scrolls V: Skyrim
# 4 Fetch data for game Worldwide Soccer Manager 2009
# 5 Fetch data for game Gauntlet: Dark Legacy
# 6 Fetch data for game Bad Boys: Miami Takedown
# 7 Fetch data for game Kaboom!
# 8 Fetch data for game Dragon Quest VIII: Journey of the Cursed King
# 9 Fetch data for game Ratchet & Clank: All 4 One
# 10 Fetch data for game Derby Stallion III
# 11 Fetch data for game Doraemon
# 12 Fetch data for game Qix
# 13 Fetch data for game High School Musical 2: Work This Out!
# 14 Fetch data for game Middle-Earth: Shadow of War
# 15 Fetch data for game Pokémon Rumble Blast
# 16 Fetch data for game Donkey Konga
# 17 Fetch data for game Lego Marvel Super Heroes
# 18 Fetch data for game Call of Duty 4: Modern Warfare
# 19 Fetch data for game Dragon Quest I & II
# 20 Fetch data for game Tak and the Power of Juju
# 21 Fetch data for game Ninja Gaiden Sigma
# 22 Fetch data for game Asteroids
# 23 Fetch data for game Puyo Puyo Sun Ketteiban
# 24 Fetch data for game 007: Quantum of Solace
# 25 Fetch data for game LEGO Star Wars III: The Clone Wars
# 26 Fetch data for game Action Bass
# 27 Fetch data for game Tenchu: Wrath of Heaven
# 28 Fetch data for game Shadow of the Colossus
# 29 Fetch data for game Brave Fencer Musashi
# 30 Fetch data for game Dance Dance Revolution Extreme 2
# 31 Fetch data for game Mortal Kombat
# 32 Fetch data for game Hot Shots Golf: Out of Bounds
# 33 Fetch data for game Commando
# 34 Fetch data for game Pilotwings
# 35 Fetch data for game Resident Evil - Code: Veronica
# 36 Fetch data for game South Park
# 37 Fetch data for game Super R.C. Pro-Am
# 38 Fetch data for game The Lord of the Rings: The Return of the King
# 39 Fetch data for game Final Fantasy XV
# 40 Fetch data for game LEGO Star Wars: The Video Game
# 41 Fetch data for game Grand Theft Auto: The Trilogy
# 42 Fetch data for game LEGO Worlds
# 43 Fetch data for game Mobile Suit Gundam: Federation vs. Zeon
# 44 Fetch data for game Need for Speed Underground 2
# 45 Fetch data for game MechAssault
# 46 Fetch data for game NCAA Football 14
# 47 Fetch data for game Derby Stallion 99
# 48 Fetch data for game Cars
# 49 Fetch data for game Mirror's Edge
# 50 Fetch data for game Rocksmith
# 51 Fetch data for game Plants vs Zombies: Garden Warfare
# 52 Fetch data for game Tom Clancy's Rainbow Six 3: Black Arrow
# 53 Fetch data for game The Elder Scrolls V: Skyrim VR
# 54 Fetch data for game Donkey Kong
# 55 Fetch data for game Guitar Hero 5
# 56 Fetch data for game Rocksmith
# 57 Fetch data for game Jampack Winter '98
# 58 Fetch data for game Fight Night Champion
# 59 Fetch data for game SingStar
# 60 Fetch data for game Pokémon Mystery Dungeon: Red Rescue Team (US weekly sales)
# 61 Fetch data for game ModNation Racers
# 62 Fetch data for game Rabbids Go Home
# 63 Fetch data for game Moon Patrol
# 64 Fetch data for game SOCOM: U.S. Navy SEALs Fireteam Bravo
# 65 Fetch data for game Supercar Street Challenge
# 66 Fetch data for game Pilotwings 64
# 67 Fetch data for game Nintendo Labo: Toy-Con 01 Variety Kit
# 68 Fetch data for game Call Of Duty 2: Big Red One
# 69 Fetch data for game Yoshi's Cookie
# 70 Fetch data for game Yakuza 3
# 71 Fetch data for game Need for Speed: Most Wanted (2012)
# 72 Fetch data for game WWE 2K14
# 73 Fetch data for game Sonic and the Black Knight
# 74 Fetch data for game The Beatles: Rock Band
# 75 Fetch data for game Guitar Hero 5
# 76 Fetch data for game Worldwide Soccer Manager 2008
# 77 Fetch data for game Dragon Age II
# 78 Fetch data for game Spider-Man 2
# 79 Fetch data for game Farming Simulator 17
# 80 Fetch data for game Crackdown 2
# 81 Fetch data for game Crash Bandicoot N. Sane Trilogy
# 82 Fetch data for game Counter-Strike
# 83 Fetch data for game Plants vs. Zombies
# 84 Fetch data for game Transformers: The Game
# 85 Fetch data for game LEGO Marvel Super Heroes 2
# 86 Fetch data for game Disney Infinity 2.0: Marvel Super Heroes
# 87 Fetch data for game Castlevania: Lords of Shadow
# 88 Fetch data for game Guitar Hero Encore: Rocks The 80s
# 89 Fetch data for game Rock Band
# 90 Fetch data for game Tom Clancy's Splinter Cell: Chaos Theory
# 91 Fetch data for game Arc the Lad
# 92 Fetch data for game Donkey Kong Jr.
# 93 Fetch data for game NBA Jam Tournament Edition
# 94 Fetch data for game Legend of Mana
# 95 Fetch data for game Mafia III
# 96 Fetch data for game Red Dead Redemption: Undead Nightmare
# 97 Fetch data for game Metal Gear Solid HD Collection
# 98 Fetch data for game EA Sports UFC
# 99 Fetch data for game NCAA Football 13
# 100 Fetch data for game Lumines: Puzzle Fusion
# 100
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Critic_Score',
#        'User_Score', 'Publisher', 'Developer', 'NA_Sales', 'PAL_Sales',
#        'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
columns = {
    'Rank': rank,
    'Name': gname,
    'Platform': platform,
    'Year': year,
    'Genre': genre,
    'Critic_Score': critic_score,
    'User_Score': user_score,
    'Publisher': publisher,
    'Developer': developer,
    'NA_Sales': sales_na,
    'PAL_Sales': sales_pal,
    'JP_Sales': sales_jp,
    'Other_Sales': sales_ot,
    'Global_Sales': sales_gl
}
print(rec_count)
df = pd.DataFrame(columns)
print(df.columns)
df = df[[
    'Rank', 'Name', 'Platform', 'Year', 'Genre',
    'Publisher', 'Developer', 'Critic_Score', 'User_Score',
    'NA_Sales', 'PAL_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']]
df.to_csv("vgsales_new.csv", sep=",", encoding='utf-8', index=False)
# Out:
# 1728
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Critic_Score',
#        'User_Score', 'Publisher', 'Developer', 'NA_Sales', 'PAL_Sales',
#        'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')
